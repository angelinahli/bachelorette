# %% [markdown]
# # The Bachelor & Race: Clean Data (Pt. 3)
# * **Filename**: clean_weeks_data.ipynb
# * **Author**: Angelina Li
# * **Date**: 09/07/2018
# * **Description**: Update master_flags_dataset to contain information on how many weeks each contestant lasted.
# * **Input**: master_flags_dataset.csv
# * **Output**: Updated master_flags_dataset.csv

# %%
import re
import pandas as pd
import os

# %%
# name key directories

input_dir = "../input"
intermed_dir = "../intermediate"

# %%
# import the master dataset
master_path = os.path.join(intermed_dir, "master_flags_dataset.csv")
df = pd.read_csv(master_path)
print(df.columns)
df.head()
# Out:
# Index(['cid', 'd1', 'd10', 'd2', 'd3', 'd4', 'd5', 'd6', 'd7', 'd8', 'd9',
#        'datetime', 'e1', 'e10', 'e2', 'e3', 'e4', 'e5', 'e6', 'e7', 'e8', 'e9',
#        'lead', 'lead_flag', 'name', 'num_contestants', 'poc', 'season', 'show',
#        'year', 'white', 'afam', 'amin', 'hisp', 'asn_paci', 'oth', 'mult',
#        'race_data_flag', 'season_comp_flag', 'lead_poc'],
#       dtype='object')
#                cid   d1  d10   d2   d3   d4   d5   d6   d7   d8   ...     \
# 0    BA_1_ALEX_M_L  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   ...
# 1   BA_01_AMANDA_M  NaN  NaN   D5   D1   D1   D1   D1  NaN  NaN   ...
# 2   BA_01_TRISTA_R  NaN  NaN   D5   D1   D1   D1   D1  NaN  NaN   ...
# 3  BA_01_SHANNON_O  NaN  NaN   D5   D1   D1   D1  NaN  NaN  NaN   ...
# 4      BA_01_KIM_X  NaN  NaN   D5   D4   D1  NaN  NaN  NaN  NaN   ...
#
#   white afam amin hisp asn_paci oth mult race_data_flag season_comp_flag  \
# 0   1.0  NaN  NaN  NaN      NaN NaN  NaN           True             True
# 1   1.0  NaN  NaN  NaN      NaN NaN  NaN           True             True
# 2   1.0  NaN  NaN  NaN      NaN NaN  NaN           True             True
# 3   1.0  NaN  NaN  NaN      NaN NaN  NaN           True             True
# 4   1.0  NaN  NaN  NaN      NaN NaN  NaN           True             True
#
#   lead_poc
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
#
# [5 rows x 40 columns]

# %%
df[["e{}".format(week) for week in range(1, 11)]].head()
# Out:
#     e1   e2   e3   e4   e5   e6   e7   e8   e9  e10
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN    W  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN    E  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN    E  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN    E  NaN  NaN  NaN  NaN  NaN  NaN

# %%
# create a var equalling the total number of weeks per season

def get_season_num_weeks(show):
    seasons = df[df["show"] == show].season.unique()
    season_num_weeks = {}
    for season in seasons:
        season_df = df[(df.season == season) & (df.show == show)]
        show_end = 10
        for week in range(10, 0, -1):
            vals = season_df["e{}".format(week)].unique()
            show_end = week
            if len(vals) > 1:
                break                
        season_num_weeks[(show, season)] = show_end
    return season_num_weeks

season_nums = get_season_num_weeks("Bachelorette")
season_nums.update(get_season_num_weeks("Bachelor"))
print(season_nums)
# Out:
# {('Bachelorette', 1): 6, ('Bachelorette', 2): 7, ('Bachelorette', 3): 8, ('Bachelorette', 4): 8, ('Bachelorette', 5): 10, ('Bachelorette', 6): 10, ('Bachelorette', 7): 10, ('Bachelorette', 8): 10, ('Bachelorette', 9): 10, ('Bachelorette', 10): 10, ('Bachelorette', 11): 9, ('Bachelorette', 12): 10, ('Bachelorette', 13): 10, ('Bachelorette', 14): 10, ('Bachelor', 1): 6, ('Bachelor', 2): 7, ('Bachelor', 3): 7, ('Bachelor', 4): 7, ('Bachelor', 5): 7, ('Bachelor', 6): 8, ('Bachelor', 7): 7, ('Bachelor', 8): 7, ('Bachelor', 9): 7, ('Bachelor', 10): 8, ('Bachelor', 11): 8, ('Bachelor', 12): 8, ('Bachelor', 13): 8, ('Bachelor', 14): 8, ('Bachelor', 15): 10, ('Bachelor', 16): 10, ('Bachelor', 17): 10, ('Bachelor', 18): 10, ('Bachelor', 19): 10, ('Bachelor', 20): 10, ('Bachelor', 21): 10, ('Bachelor', 22): 10}

# %%
def get_num_weeks(row):
    return season_nums.get((row["show"], row["season"]))

df["season_num_weeks"] = df.apply(get_num_weeks, axis=1)
df.head()
# Out:
#                cid   d1  d10   d2   d3   d4   d5   d6   d7   d8  \
# 0    BA_1_ALEX_M_L  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1   BA_01_AMANDA_M  NaN  NaN   D5   D1   D1   D1   D1  NaN  NaN
# 2   BA_01_TRISTA_R  NaN  NaN   D5   D1   D1   D1   D1  NaN  NaN
# 3  BA_01_SHANNON_O  NaN  NaN   D5   D1   D1   D1  NaN  NaN  NaN
# 4      BA_01_KIM_X  NaN  NaN   D5   D4   D1  NaN  NaN  NaN  NaN
#
#         ...        afam amin hisp asn_paci oth mult race_data_flag  \
# 0       ...         NaN  NaN  NaN      NaN NaN  NaN           True
# 1       ...         NaN  NaN  NaN      NaN NaN  NaN           True
# 2       ...         NaN  NaN  NaN      NaN NaN  NaN           True
# 3       ...         NaN  NaN  NaN      NaN NaN  NaN           True
# 4       ...         NaN  NaN  NaN      NaN NaN  NaN           True
#
#   season_comp_flag lead_poc season_num_weeks
# 0             True    False                6
# 1             True    False                6
# 2             True    False                6
# 3             True    False                6
# 4             True    False                6
#
# [5 rows x 41 columns]

# %%
df.season_num_weeks.unique()
# Out:
# array([ 6,  7,  8, 10,  9])

# %%
# get number of weeks that each candidate spent on the show
def get_cont_num_weeks(row):
    if row["lead_flag"]:
        return None
    weeks = row[["e{}".format(week) for week in range(1, 11)]]
    
    for i in range(row["season_num_weeks"] - 1, -1, -1):
        val = weeks[i]
        week = i + 1
        if not pd.isnull(val):
            return week

df["num_weeks"] = df.apply(get_cont_num_weeks, axis=1)
df.head()
# Out:
#                cid   d1  d10   d2   d3   d4   d5   d6   d7   d8    ...     \
# 0    BA_1_ALEX_M_L  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    ...
# 1   BA_01_AMANDA_M  NaN  NaN   D5   D1   D1   D1   D1  NaN  NaN    ...
# 2   BA_01_TRISTA_R  NaN  NaN   D5   D1   D1   D1   D1  NaN  NaN    ...
# 3  BA_01_SHANNON_O  NaN  NaN   D5   D1   D1   D1  NaN  NaN  NaN    ...
# 4      BA_01_KIM_X  NaN  NaN   D5   D4   D1  NaN  NaN  NaN  NaN    ...
#
#   amin hisp asn_paci oth mult race_data_flag season_comp_flag lead_poc  \
# 0  NaN  NaN      NaN NaN  NaN           True             True    False
# 1  NaN  NaN      NaN NaN  NaN           True             True    False
# 2  NaN  NaN      NaN NaN  NaN           True             True    False
# 3  NaN  NaN      NaN NaN  NaN           True             True    False
# 4  NaN  NaN      NaN NaN  NaN           True             True    False
#
#   season_num_weeks num_weeks
# 0                6       NaN
# 1                6       6.0
# 2                6       6.0
# 3                6       5.0
# 4                6       4.0
#
# [5 rows x 42 columns]

# %%
df["num_weeks"].unique()
# Out:
# array([ nan,   6.,   5.,   4.,   3.,   2.,   1.,   7.,   8.,  10.,   9.])

# %%
def get_perc_weeks(row):
    return row["num_weeks"] / row["season_num_weeks"]

df["perc_weeks"] = df.apply(get_perc_weeks, axis=1)
df.head()
# Out:
#                cid   d1  d10   d2   d3   d4   d5   d6   d7   d8    ...      \
# 0    BA_1_ALEX_M_L  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    ...
# 1   BA_01_AMANDA_M  NaN  NaN   D5   D1   D1   D1   D1  NaN  NaN    ...
# 2   BA_01_TRISTA_R  NaN  NaN   D5   D1   D1   D1   D1  NaN  NaN    ...
# 3  BA_01_SHANNON_O  NaN  NaN   D5   D1   D1   D1  NaN  NaN  NaN    ...
# 4      BA_01_KIM_X  NaN  NaN   D5   D4   D1  NaN  NaN  NaN  NaN    ...
#
#   hisp asn_paci oth mult race_data_flag season_comp_flag lead_poc  \
# 0  NaN      NaN NaN  NaN           True             True    False
# 1  NaN      NaN NaN  NaN           True             True    False
# 2  NaN      NaN NaN  NaN           True             True    False
# 3  NaN      NaN NaN  NaN           True             True    False
# 4  NaN      NaN NaN  NaN           True             True    False
#
#   season_num_weeks num_weeks perc_weeks
# 0                6       NaN        NaN
# 1                6       6.0   1.000000
# 2                6       6.0   1.000000
# 3                6       5.0   0.833333
# 4                6       4.0   0.666667
#
# [5 rows x 43 columns]

# %%
def is_winner(row):
    if row["lead_flag"]:
        return
    weeks = row[["e{}".format(week) for week in range(1, 11)]].tolist()
    return "W" in weeks

df["winner_flag"] = df.apply(is_winner, axis=1)
df.head()
# Out:
#                cid   d1  d10   d2   d3   d4   d5   d6   d7   d8     ...      \
# 0    BA_1_ALEX_M_L  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     ...
# 1   BA_01_AMANDA_M  NaN  NaN   D5   D1   D1   D1   D1  NaN  NaN     ...
# 2   BA_01_TRISTA_R  NaN  NaN   D5   D1   D1   D1   D1  NaN  NaN     ...
# 3  BA_01_SHANNON_O  NaN  NaN   D5   D1   D1   D1  NaN  NaN  NaN     ...
# 4      BA_01_KIM_X  NaN  NaN   D5   D4   D1  NaN  NaN  NaN  NaN     ...
#
#   asn_paci oth mult race_data_flag season_comp_flag lead_poc season_num_weeks  \
# 0      NaN NaN  NaN           True             True    False                6
# 1      NaN NaN  NaN           True             True    False                6
# 2      NaN NaN  NaN           True             True    False                6
# 3      NaN NaN  NaN           True             True    False                6
# 4      NaN NaN  NaN           True             True    False                6
#
#   num_weeks perc_weeks winner_flag
# 0       NaN        NaN        None
# 1       6.0   1.000000        True
# 2       6.0   1.000000       False
# 3       5.0   0.833333       False
# 4       4.0   0.666667       False
#
# [5 rows x 44 columns]

# %%
# create flag for first impression rose
df["fimp_rose"] = df.e1.map(lambda val: val == "R1")
df[df.fimp_rose == True][["cid", "name", "show", "season", "year", "e1", "poc"]].head()
# Out:
#                    cid         name      show  season  year  e1    poc
# 110      BA_05_TRISH_S      Trish S  Bachelor       5  2004  R1  False
# 159     BA_07_Sarah W.     Sarah w.  Bachelor       7  2005  R1  False
# 166        BA_07_Kerry        Kerry  Bachelor       7  2005  R1  False
# 212       BA_09_LISA_B       Lisa B  Bachelor       9  2006  R1  False
# 244  BA_10_STEPHANIE_T  Stephanie T  Bachelor      10  2007  R1  False

# %%
df.columns
# Out:
# Index(['cid', 'd1', 'd10', 'd2', 'd3', 'd4', 'd5', 'd6', 'd7', 'd8', 'd9',
#        'datetime', 'e1', 'e10', 'e2', 'e3', 'e4', 'e5', 'e6', 'e7', 'e8', 'e9',
#        'lead', 'lead_flag', 'name', 'num_contestants', 'poc', 'season', 'show',
#        'year', 'white', 'afam', 'amin', 'hisp', 'asn_paci', 'oth', 'mult',
#        'race_data_flag', 'season_comp_flag', 'lead_poc', 'season_num_weeks',
#        'num_weeks', 'perc_weeks', 'winner_flag', 'fimp_rose'],
#       dtype='object')

# %%
# drop seasons we don't have race data for
df = df[df.season_comp_flag == True]
df = df[["cid", "name", "lead", "lead_flag", "num_contestants", 
         "poc", "season", "show", "year", "white", "afam", "amin", 
         "hisp", "asn_paci", "oth", "mult", 
         "num_weeks", "season_num_weeks", "perc_weeks",
         "winner_flag", "lead_poc", "fimp_rose"]]
df.head()
# Out:
#                cid         name         lead  lead_flag  num_contestants  \
# 0    BA_1_ALEX_M_L  Alex Michel  Alex Michel       True               25
# 1   BA_01_AMANDA_M     Amanda M  Alex Michel      False               25
# 2   BA_01_TRISTA_R     Trista R  Alex Michel      False               25
# 3  BA_01_SHANNON_O    Shannon O  Alex Michel      False               25
# 4      BA_01_KIM_X        Kim X  Alex Michel      False               25
#
#      poc  season      show  year  white    ...     hisp  asn_paci  oth  mult  \
# 0  False       1  Bachelor  2002    1.0    ...      NaN       NaN  NaN   NaN
# 1  False       1  Bachelor  2002    1.0    ...      NaN       NaN  NaN   NaN
# 2  False       1  Bachelor  2002    1.0    ...      NaN       NaN  NaN   NaN
# 3  False       1  Bachelor  2002    1.0    ...      NaN       NaN  NaN   NaN
# 4  False       1  Bachelor  2002    1.0    ...      NaN       NaN  NaN   NaN
#
#    num_weeks  season_num_weeks  perc_weeks  winner_flag  lead_poc fimp_rose
# 0        NaN                 6         NaN         None     False     False
# 1        6.0                 6    1.000000         True     False     False
# 2        6.0                 6    1.000000        False     False     False
# 3        5.0                 6    0.833333        False     False     False
# 4        4.0                 6    0.666667        False     False     False
#
# [5 rows x 22 columns]

# %%
df_path = os.path.join("..", "master_flags_dataset.csv")
df.to_csv(df_path)
